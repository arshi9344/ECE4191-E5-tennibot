# %% [markdown]
# # Code for line detection:
# Adjust threshold based on surface

# %%
import time
import board
import busio
from IPython import display
import adafruit_tcs34725
from adafruit_extended_bus import ExtendedI2C as I2C

# Use I2C bus 3 with custom SDA and SCL pins
i2c = I2C(3)  # This specifies I2C bus 3

# Initialize the TCS34725 sensor
sensor = adafruit_tcs34725.TCS34725(i2c)

sensor.integration_time = 200
sensor.gain = 60

# Variable to change upon detecting a color shift
color_detected = 0

# Set initial threshold values for color change detection
threshold = 1000  # Adjust this value based on sensitivity requirements

# Store the initial color values as a reference
initial_r, initial_g, initial_b, _ = sensor.color_raw

print("Monitoring color changes...")

while True:
    # Read the current color values
    r, g, b, c = sensor.color_raw

    # Calculate the difference in color values
    r_diff = abs(r - initial_r)
    g_diff = abs(g - initial_g)
    b_diff = abs(b - initial_b)

    # Detect a color shift based on the threshold
    if r_diff > threshold or g_diff > threshold or b_diff > threshold:
        color_detected = 1
        print("Color shift detected! Variable set to 1.")
    else:
        color_detected = 0

    # Print current status (optional)
    print(f"Color detected: R={r}, G={g}, B={b}, Variable={color_detected}")

    # Optional: Update initial color if you want to detect a shift back
    # initial_r, initial_g, initial_b = r, g, b

    # Small delay to avoid excessive CPU usage
    time.sleep(0.1)
# Out:
# Monitoring color changes...
# Color detected: R=16435, G=17668, B=14978, Variable=0
# Color detected: R=16448, G=17680, B=14984, Variable=0
# Color detected: R=16433, G=17667, B=14974, Variable=0
# Color detected: R=16439, G=17675, B=14977, Variable=0
# Color detected: R=16466, G=17689, B=14992, Variable=0
# Color detected: R=16394, G=17601, B=14908, Variable=0
# Color detected: R=15811, G=16840, B=14589, Variable=0
# Color detected: R=15928, G=16963, B=14712, Variable=0
# Color detected: R=15688, G=16720, B=14468, Variable=0
# Color shift detected! Variable set to 1.
# Color detected: R=8445, G=8584, B=7821, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=8448, G=8586, B=7816, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=12627, G=13240, B=11567, Variable=1
# Color detected: R=16069, G=17110, B=14839, Variable=0
# Color detected: R=16070, G=17113, B=14832, Variable=0
# Color detected: R=16070, G=17112, B=14831, Variable=0
# Color detected: R=16055, G=17089, B=14809, Variable=0
# Color shift detected! Variable set to 1.
# Color detected: R=10565, G=10927, B=9711, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=8478, G=8643, B=7878, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=11656, G=12162, B=10709, Variable=1
# Color detected: R=15992, G=17019, B=14767, Variable=0
# Color detected: R=15986, G=17015, B=14765, Variable=0
# Color detected: R=15997, G=17029, B=14774, Variable=0
# Color detected: R=15996, G=17029, B=14769, Variable=0
# Color detected: R=16003, G=17040, B=14777, Variable=0
# Color detected: R=16024, G=17054, B=14789, Variable=0
# Color detected: R=16034, G=17084, B=14798, Variable=0
# Color detected: R=16060, G=17137, B=14837, Variable=0
# Color detected: R=16094, G=17172, B=14872, Variable=0
# Color detected: R=16149, G=17222, B=14929, Variable=0
# Color detected: R=16172, G=17243, B=14954, Variable=0
# Color detected: R=16196, G=17265, B=14978, Variable=0
# Color detected: R=16219, G=17293, B=14986, Variable=0
# Color detected: R=16026, G=17146, B=14837, Variable=0
# Color detected: R=16008, G=17140, B=14835, Variable=0
# Color detected: R=16094, G=17190, B=14888, Variable=0
# Color shift detected! Variable set to 1.
# Color detected: R=11404, G=11811, B=10418, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=6630, G=6020, B=5623, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=14995, G=15927, B=13725, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=15193, G=16197, B=13948, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=15230, G=16209, B=13964, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=15185, G=16196, B=13947, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=15169, G=16184, B=13938, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=15197, G=16198, B=13950, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=15193, G=16207, B=13955, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=15341, G=16327, B=14070, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=15328, G=16310, B=14042, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=15075, G=16007, B=13738, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=14744, G=15657, B=13387, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=14368, G=15223, B=12963, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=14393, G=15221, B=12952, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=14374, G=15235, B=12957, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=14346, G=15206, B=12924, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=14353, G=15206, B=12926, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=14353, G=15205, B=12923, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=14355, G=15207, B=12924, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=14346, G=15201, B=12915, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=14305, G=15158, B=12878, Variable=1
# Color shift detected! Variable set to 1.
# Color detected: R=