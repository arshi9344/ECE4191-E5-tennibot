# %%
#!pip install -r https://raw.githubusercontent.com/ultralytics/yolov5/master/requirements.txt

# %%
import torch 

# FOR WINDOWS: 
#import pathlib
#emp = pathlib.PosixPath
#pathlib.PosixPath = pathlib.WindowsPath


model = torch.hub.load('ultralytics/yolov5', 'custom', path='best.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /home/ece4191e5/.cache/torch/hub/master.zip
# YOLOv5 🚀 2024-9-9 Python-3.10.12 torch-2.3.0 CPU
#
# Fusing layers...
# Model summary: 157 layers, 1760518 parameters, 0 gradients, 4.1 GFLOPs
# Adding AutoShape...

# %%
results = model('test_image/tennis.jpg')

# Display results
results.show()  # Show predictions
results.save()  # Save predictions to file
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720 at 0xFFFF192C7430>
# Saved 1 image to runs/detect/exp3
